# %%
import pandas as pd
import numpy as np
### Step 1: Import Data
df = pd.read_csv("chipotle.tsv",sep="\t")
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Dataset Overview

# %%
df.shape
# Out:
# (4622, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   float64
#  5   total_price         4622 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 216.8+ KB

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description', 'item_price',
#        'total_price'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df.describe(include = "all")
# Out:
#            order_id     quantity     item_name choice_description  \
# count   4622.000000  4622.000000          4622               3376
# unique          NaN          NaN            50               1043
# top             NaN          NaN  Chicken Bowl        [Diet Coke]
# freq            NaN          NaN           726                134
# mean     927.254868     1.075725           NaN                NaN
# std      528.890796     0.410186           NaN                NaN
# min        1.000000     1.000000           NaN                NaN
# 25%      477.250000     1.000000           NaN                NaN
# 50%      926.000000     1.000000           NaN                NaN
# 75%     1393.000000     1.000000           NaN                NaN
# max     1834.000000    15.000000           NaN                NaN
#
#          item_price  total_price
# count   4622.000000  4622.000000
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# ...

# %% [markdown]
# ###loc vs iloc

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# Select all rows with quantity = 15 and item name = Nantucket Nectar

# %%
df.loc[(df.quantity == 15) | (df.item_name == "Nantucket Nectar")]
# Out:
#       order_id  quantity                     item_name  \
# 2            1         1              Nantucket Nectar
# 22          11         1              Nantucket Nectar
# 105         46         1              Nantucket Nectar
# 173         77         1              Nantucket Nectar
# 205         91         1              Nantucket Nectar
# 436        189         1              Nantucket Nectar
# 601        247         2              Nantucket Nectar
# 925        381         1              Nantucket Nectar
# 1356       553         1              Nantucket Nectar
# 1585       641         1              Nantucket Nectar
# 1626       656         1              Nantucket Nectar
# 1706       690         1              Nantucket Nectar
# 2162       872         1              Nantucket Nectar
# 2379       947         2              Nantucket Nectar
# 2381       947         1              Nantucket Nectar
# 2430       965         1              Nantucket Nectar
# ...

# %%
df.loc[(df.quantity == 2) & (df.item_name == "Nantucket Nectar"),["order_id","choice_description","item_price"]]
# Out:
#       order_id         choice_description item_price
# 601        247  [Pineapple Orange Banana]     $6.78
# 2379       947             [Peach Orange]     $6.78

# %%
df.iloc[[10]]
# Out:
#     order_id  quantity            item_name choice_description item_price
# 10         5         1  Chips and Guacamole                NaN     $4.45

# %%
df.iloc[1:5, 0:-1]
# Out:
#    order_id  quantity                              item_name  \
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description
# 1                                       [Clementine]
# 2                                            [Apple]
# 3                                                NaN
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...

# %%
df.iloc[1:5,-1]
# Out:
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98
# Name: item_price, dtype: object

# %% [markdown]
# ###Data Manipulation

# %%
## 'O' python objects
df.item_price.dtype
# Out:
# dtype('O')

# %% [markdown]
# **Apply()**
#
# ---

# %%
df.item_price = df.item_price.apply(lambda x: float(x[1:]))

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
df["total_price"] = df["item_price"] * df["quantity"]
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  total_price
# 0                                                NaN        2.39         2.39
# 1                                       [Clementine]        3.39         3.39
# 2                                            [Apple]        3.39         3.39
# 3                                                NaN        2.39         2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98        33.96

# %%
df["total_price"].sum()
# Out:
# 39237.02

# %% [markdown]
# Which was the most ordered item
#
# ---

# %%
df.groupby("item_name")["quantity"].sum().sort_values(ascending = False)[0:1]
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %%
df.groupby("item_name")["quantity"].sum().sort_values(ascending = False).head(5)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %%
#Unique value
df.item_name.value_counts().count()
# Out:
# 50

# %%
df.item_name.nunique()
# Out:
# 50
